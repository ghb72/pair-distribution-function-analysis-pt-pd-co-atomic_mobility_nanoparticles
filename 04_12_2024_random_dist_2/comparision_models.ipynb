# %%
import pandas as pd
import matplotlib.pyplot as plt

Ni = pd.read_csv('C:\\Users\\guill\\OneDrive\\Documentos\\Tesis\\Proyect\\04_12_2024_random_dist_2\\randrad1_co\\Mix-co-radrand_d2.txt', sep= '\s+')
Pt = pd.read_csv('C:\\Users\\guill\\OneDrive\\Documentos\\Tesis\\Proyect\\04_12_2024_random_dist_2\\randrad2_co\\Mix-co-radrand2_d2.txt', sep= '\s+')

fig, ax =plt.subplots(figsize=(10,4), layout='constrained')
ax.plot(Pt['#r(A)'], Pt['G(r)'], color = 'black', label = 'Co Fuera')
ax.plot(Ni['#r(A)'], Ni['G(r)'], color = 'red', label = 'Co Dentro')


ax.set_xlabel('r [$\\AA$]')
ax.set_xlim([0,40])
ax.set_ylabel('G(r)')
#ax.set_title('Comparación de PDFs para nanopartículas de 3nm con diferentes estructuras')
#ax.grid('True', linestyle='-')
ax.legend()
plt.rc('font', size=12)
plt.rcParams['font.family'] = 'serif'
plt.show()
