# %%
import pandas as pd
import matplotlib.pyplot as plt

Ni = pd.read_csv('C:/Users/guill/OneDrive/Documentos/Tesis/Proyect/15_de_marzo/Ni_100/Ni-FCC_d.txt', sep= '\s+')
Pt = pd.read_csv('C:/Users/guill/OneDrive/Documentos/Tesis/Proyect/15_de_marzo/Pt_100/Pt-FCC_d.txt', sep= '\s+')

fig, ax =plt.subplots(figsize=(10,4), layout='constrained')
ax.plot(Pt['#r(A)'], Pt['G(r)']+0.15, color = 'black', label = 'Pt')
ax.plot(Ni['#r(A)'], Ni['G(r)']-0.15, color = 'red', label = 'Ni')


ax.set_xlabel('r [$\\AA$]')
ax.set_xlim([0,25])
ax.set_ylabel('G(r)')
#ax.set_title('Comparación de PDFs para nanopartículas de 3nm con diferentes estructuras')
#ax.grid('True', linestyle='-')
ax.legend()
plt.rc('font', size=12)
plt.rcParams['font.family'] = 'serif'
plt.show()
