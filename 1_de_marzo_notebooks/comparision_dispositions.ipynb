# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
import matplotlib as mpl

blue = '#233652'
brown = '#33260D'
lightblue = '#B6C1D1'

Ptcs50 = pd.read_csv('C:\\Users\\guill\\OneDrive\\Documentos\\Tesis\\Proyect\\1_de_marzo_notebooks\\NcsPt0.5\\Pt_0.5_cs_d.txt', sep = '\s+')
j50 = pd.read_csv('C:\\Users\\guill\\OneDrive\\Documentos\\Tesis\\Proyect\\1_de_marzo_notebooks\\Janus_0.5\\janus-0.5_d.txt', sep = '\s+')
S1 = pd.read_csv('C:\\Users\\guill\\OneDrive\\Documentos\\Tesis\\Proyect\\1_de_marzo_notebooks\\Ni_0.5_sandwich\\Ni_0.5_sandwich_d.txt', sep = '\s+')
# Out:
# <>:10: SyntaxWarning: invalid escape sequence '\s'
# <>:11: SyntaxWarning: invalid escape sequence '\s'
# <>:12: SyntaxWarning: invalid escape sequence '\s'
# <>:10: SyntaxWarning: invalid escape sequence '\s'
# <>:11: SyntaxWarning: invalid escape sequence '\s'
# <>:12: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\guill\AppData\Local\Temp\ipykernel_14236\2501981750.py:10: SyntaxWarning: invalid escape sequence '\s'
#   Ptcs50 = pd.read_csv('C:\\Users\\guill\\OneDrive\\Documentos\\Tesis\\Proyect\\1_de_marzo_notebooks\\NcsPt0.5\\Pt_0.5_cs_d.txt', sep = '\s+')
# C:\Users\guill\AppData\Local\Temp\ipykernel_14236\2501981750.py:11: SyntaxWarning: invalid escape sequence '\s'
#   j50 = pd.read_csv('C:\\Users\\guill\\OneDrive\\Documentos\\Tesis\\Proyect\\1_de_marzo_notebooks\\Janus_0.5\\janus-0.5_d.txt', sep = '\s+')
# C:\Users\guill\AppData\Local\Temp\ipykernel_14236\2501981750.py:12: SyntaxWarning: invalid escape sequence '\s'
# ...

# %%
fig, ax =plt.subplots(figsize=(8,7), layout='constrained', facecolor='#D1C8B6')
ax.plot(Ptcs50['#r(A)'], Ptcs50['G(r)']+0.8, label = '50% Pt dentro, 50% Ni fuera', color = blue, lw=3)
ax.plot(j50['#r(A)'], j50['G(r)']+0.4, label = '50% Pt, 50% Ni', color = blue, lw=3)
ax.plot(S1['#r(A)'], S1['G(r)'], label = '50% Ni dentro, 50% Pt fuera', color = blue, lw = 3)




#ax.plot(HCP['#r(A)'], HCP['G(r)']+0.8, label = 'HCP', color = blue, lw=3)
#ax.plot(ICO['#r(A)'], ICO['G(r)']+1.2, color = 'green', label = 'ICO')


ax.set_xlabel('r [$\\AA$]', color=blue, weight='bold')
ax.set_facecolor('#D1C8B6')
ax.set_xlim([0,25])
ax.set_ylabel('G(r)', color=blue, weight='bold')
#ax.set_title('Comparación de PDFs para nanopartículas de 3nm con diferentes estructuras')
#ax.grid('True', linestyle='-')
#ax.legend()


ax.text(*[18,1], 'Core-Shell', fontsize=20, rotation_mode='anchor', color = blue)
ax.text(*[18,0.2], 'Sandwich', fontsize=20, rotation_mode='anchor', color = blue)
ax.text(*[18,0.6], 'Janus', fontsize=20, rotation_mode='anchor', color = blue)




ax.tick_params(labelcolor=blue)
for axis in ['top', 'bottom', 'left', 'right']:
    ax.spines[axis].set_color(blue)
    ax.spines[axis].set(linewidth = 3)



plt.rc('font', size=20, weight='bold')

#fpath = Path(mpl.get_data_path(), "C:/Users/guill/Downloads/Fira_Sans/FiraSans-Medium.ttf")

plt.rcParams['font.family'] = 'sans-serif'
plt.show()
# Out:
# C:\Users\guill\AppData\Local\Temp\ipykernel_14236\4135812696.py:2: UserWarning: This figure was using a layout engine that is incompatible with subplots_adjust and/or tight_layout; not calling subplots_adjust.
#   fig.subplots_adjust(hspace=0)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 15
#       6 ax[2].plot(S1['#r(A)'], S1['G(r)'], label = '50% Ni dentro, 50% Pt fuera', color = blue, lw = 3)
#      11 #ax.plot(HCP['#r(A)'], HCP['G(r)']+0.8, label = 'HCP', color = blue, lw=3)
#      12 #ax.plot(ICO['#r(A)'], ICO['G(r)']+1.2, color = 'green', label = 'ICO')
# ---> 15 ax.set_xlabel('r [$\\AA$]', color=blue, weight='bold')
#      16 ax.set_facecolor('#D1C8B6')
#      17 ax.set_xlim([0,25])
#
# AttributeError: 'numpy.ndarray' object has no attribute 'set_xlabel'

# %%
ancho_cm = 16
alto_cm = 16
ancho_pulg = ancho_cm / 2.54
alto_pulg = alto_cm / 2.54

fig, ax =plt.subplots(3,1, sharex=True, figsize=(ancho_pulg, alto_pulg))
fig.subplots_adjust(hspace=0)

ax[0].plot(Ptcs50['#r(A)'], Ptcs50['G(r)'], label = '50% Pt dentro, 50% Ni fuera', color = 'red', lw=1.6)
ax[1].plot(j50['#r(A)'], j50['G(r)'], label = '50% Pt, 50% Ni', lw=1.6, color = 'red')
ax[2].plot(S1['#r(A)'], S1['G(r)'], label = '50% Ni dentro, 50% Pt fuera',  lw = 1.6, color = 'red')

ax[2].set_xlabel('r [$\\AA$]')
ax[1].set_ylabel('Atomic PDF G(r)')

for i in range(3):
    ax[i].set_xlim([0,22.5])
    #ax[i].label_outer()
    for axis in ['top', 'bottom', 'left', 'right']:
        ax[i].spines[axis].set(linewidth = 1.6)


ax[0].text(*[12.5,0.2], 'Core-Shell', rotation_mode='anchor')
ax[1].text(*[12.5,0.2], 'Janus', rotation_mode='anchor')
ax[2].text(*[12.5,0.2], 'Sandwich', rotation_mode='anchor')




plt.rc('font', size=12)

#fpath = Path(mpl.get_data_path(), "C:/Users/guill/Downloads/Fira_Sans/FiraSans-Medium.ttf")

plt.rcParams['font.serif'] = ['Times New Roman']
plt.show()
