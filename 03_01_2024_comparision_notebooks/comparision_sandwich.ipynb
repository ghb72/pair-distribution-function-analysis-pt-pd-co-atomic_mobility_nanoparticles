# %%
import pandas as pd
import matplotlib.pyplot as plt

FCC = pd.read_csv('../03_15_2024_Pt_Ni_rand_dist/Pt_100/Pt-FCC_d.txt', sep= '\s+')
Ni = pd.read_csv('../03_15_2024_Pt_Ni_rand_dist/Ni_100/Ni-FCC_d.txt', sep= '\s+')
S1 = pd.read_csv('C:\\Users\\guill\\OneDrive\\Documentos\\Tesis\\Proyect\\03_01_2025_sandwich_coreshell_janus_notebooks\\Ni_0.5_sandwich\\Ni_0.5_sandwich_d.txt', sep = '\s+')
S2 = pd.read_csv('C:\\Users\\guill\\OneDrive\\Documentos\\Tesis\\Proyect\\03_01_2025_sandwich_coreshell_janus_notebooks\\Pt_0.5_sandwich\\Pt_0.5_sandwich_d.txt', sep = '\s+')

fig, ax =plt.subplots(figsize=(10,8), layout='constrained')
ax.plot(FCC['#r(A)'], FCC['G(r)']+0.6, color = 'black', label = '100% Pt')
ax.plot(S1['#r(A)'], S1['G(r)'], label = '50% Ni dentro, 50% Pt fuera')
ax.plot(S2['#r(A)'], S2['G(r)']+0.3, label = '50% Pt dentro, 50% Ni fuera')
ax.plot(Ni['#r(A)'], Ni['G(r)']-0.3, color = 'red', label = '100% Ni')


ax.set_xlabel('r [$\\AA$]')
ax.set_xlim([0,25])
ax.set_ylabel('G(r)')
#ax.set_title('Comparación de PDFs para nanopartículas janus de 3nm con \n diferententes proporciones de componentes')
#ax.grid('True', linestyle='-')
ax.legend()
plt.rc('font', size=12)
plt.rcParams['font.family'] = 'serif'
plt.show()
