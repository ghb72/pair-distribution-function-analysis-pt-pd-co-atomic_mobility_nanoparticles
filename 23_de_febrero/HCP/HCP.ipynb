# %% [markdown]
# # Estructura HCP sin MD
# ## Empezamos por hacer nuestro Modelo
# Creamos nuestro Modelo HCP de 10 capas, distancia interatómica de 2.78 Angstroms y hacemos un radcut de 15 A, y de igual manera lo visualizamos con jmol

# %%
from sys import path
import os
dir_actual = os.getcwd()
path.insert(0, 'C:/Users/guill/OneDrive/Documentos/Tesis/Proyect')

import myfuncions.tools_f as tools
import subprocess as sbp

name='HCP.xyz'
atpos, eleList = tools.leer_xyz(name)
tools.show_percent(atpos,eleList)

sbp.run(['java', '-jar', 'C:\\Users\\guill\\Downloads\\Jmol-16.1.41-binary\\jmol-16.1.41\\Jmol.jar', name])
# Out:
# atomos totales : 928
# Pt : 100.0 %, 928
# CompletedProcess(args=['java', '-jar', 'C:\\Users\\guill\\Downloads\\Jmol-16.1.41-binary\\jmol-16.1.41\\Jmol.jar', 'HCP.xyz'], returncode=0)

# %% [markdown]
# Aquí lo obtenido:

# %% [markdown]
# ![HCP.jpg](attachment:HCP.jpg)
# ![HCP_otherview.jpg](attachment:HCP_otherview.jpg)

# %% [markdown]
# ## Análisis del modelo
# Se hace el análisis mostrado la distribución radial y fracción de atomos por radio

# %%
import myfuncions.graphs_f as myplt
import matplotlib.pyplot as plt
dr = 0.1
radios, fracc, conteo_total, conteo_interes = myplt.dump_fracc_atpr(atpos,'Pt',dr)
fig, ax =plt.subplots(figsize=(10,2.5), layout='constrained')
ax.plot(radios, conteo_total, label=('Atomos por radio'), color = 'black')
ax.set_xlabel('Radio [$\\AA$]')
ax.set_ylabel('Átomos por radio')
ax.set_title('Cantidad de Átomos por radio para nanopartícula HCP de 3 nm')
ypos_text = max(conteo_total)/2
ax.text(1,ypos_text,f'$\Delta r = {dr} \AA$', va='bottom')
#ax.legend()
plt.show()

# %%
dr = 0.2
radios, fracc, conteo_total, conteo_interes = myplt.dump_fracc_atpr(atpos,'Pt',dr)
fig, ax =plt.subplots(figsize=(10,2.5), layout='constrained')
ax.plot(radios, conteo_total, label=('Atomos por radio'), color = 'black')
ax.set_xlabel('Radio [$\\AA$]')
ax.set_ylabel('Átomos por radio')
ax.set_title('Cantidad de Átomos por radio para nanopartícula HCP de 3 nm')
ypos_text = max(conteo_total)/2
ax.text(1,ypos_text,f'$\Delta r = {dr} \AA$', va='bottom')
#ax.legend()
plt.show()

# %%
dr = 1.4
radios, fracc, conteo_total, conteo_interes = myplt.dump_fracc_atpr(atpos,'Pt',dr)
fig, ax =plt.subplots(figsize=(10,2.5), layout='constrained')
ax.plot(radios, conteo_total, label=('Atomos por radio'), color = 'black')
ax.set_xlabel('Radio [$\\AA$]')
ax.set_ylabel('Átomos por radio')
ax.set_title('Cantidad de Átomos por radio para nanopartícula HCP de 3 nm')
ypos_text = max(conteo_total)/2
ax.text(1,ypos_text,f'$\Delta r = {dr} \AA$', va='bottom')
#ax.legend()
plt.show()

# %% [markdown]
# ## Aquí se hace el PDF y la gráfica

# %%
import PDF.runner as pdf
pdf.run_pdf_noMD(f'{name[:-4]}.xyz', dir_actual, 1600,0.02,9,9)
# Out:
# c:\Users\guill\OneDrive\Documentos\Tesis\Proyect\23_de_febrero\HCP
#
#          928  atomos       430128  pares
#  Rango de distancias    2.77999902     -   29.9846001
#  Distancias promedio    15.4326630
#  Factor de normalizacion    33947.9102

# %% [markdown]
# Hacemos la gráfica PDF

# %%
import pandas as pd
import matplotlib.pyplot as plt


df_FCC= pd.read_csv(f'{name[:-4]}.txt', sep='\s+')

fig, ax =plt.subplots(figsize=(10,5), layout='constrained')
ax.plot(df_FCC['#r(A)'], df_FCC['G(r)'], color = 'black')


ax.set_xlabel('r [$\\AA$]')
ax.set_xlim([0,30])
ax.set_ylabel('G(r)')
ax.set_title('PDF para nanopartícula de 3nm HCP')
#ax.grid('True', linestyle='-')
ax.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
